# %% [markdown]
# # OUR AIM - TRAINING SUPER MARIO !
#
# To use Reinforcent Learning to make mario automatically play the game. L-Lets go! 🍄
#
# ![](https://www.notebookcheck.net/fileadmin/Notebooks/News/_nc3/2DD297B4_9BA0_4828_A4A2_149A8A73AF52.png)

# %% [markdown]
# # INTRODUCTION TO OPEN AI GYM
#
# OpenAi is an "Open source interface to reinforcement learning tasks.
# The gym library provides an easy-to-use suite of reinforcement learning tasks." (https://gym.openai.com/)
#
# Basically gives you multiple environments out of the box for you to train machine learning.
#
# ![](https://miro.medium.com/max/1318/1*ZHISh_zLYIlJPTq_6lX5LQ.png)
#
# OpenAI Gym is a toolkit for developing and comparing reinforcement learning algorithms. It supports teaching agents everything from walking to playing games like pong or pinball. Gym is an open source interface to reinforcement learning tasks. Gym provides an environment and its is upto the developer to implement any reinforcement learning algorithms. Developers can write agent using existing numerical computation library, such as TensorFlow or Theano. (from : https://medium.com/@ashish_fagna/understanding-openai-gym-25c79c06eccb)

# %% [markdown]
# ## Installing gym and nes py

# %%
# !pip install -q gym_super_mario_bros==7.3.0 nes_py
# Out:
#      |████████████████████████████████| 198 kB 15.2 MB/s
#      |████████████████████████████████| 77 kB 5.8 MB/s
#      |████████████████████████████████| 1.1 MB 23.6 MB/s
#   Building wheel for nes-py (setup.py) ... done

# %% [markdown]
# ## For rendering and display remotely on kaggle notebook
#
# Since you are using a remote server extra code needs to be added to render mario in your notebook itself.
# https://stackoverflow.com/a/45179251

# %%
# !xvfb-run -s "-screen 0 1400x900x24" jupyter notebook
# Out:
# /bin/bash: xvfb-run: command not found

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

# %% [markdown]
# Lets create a function to render the game state in notebook.

# %%
def show_state(env, step=0, info=""):
    plt.figure(3)
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title("Step: %d %s" % (step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %% [markdown]
# # INITIAL RUN

# %% [markdown]
# ### 1. lets import all the functions needed.

# %%
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace

from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %% [markdown]
# There are seven unique SIMPLE_MOVEMENT values.

# %%
SIMPLE_MOVEMENT
# Out:
# [['NOOP'],
#  ['right'],
#  ['right', 'A'],
#  ['right', 'B'],
#  ['right', 'A', 'B'],
#  ['A'],
#  ['left']]

# %% [markdown]
# ### 2. We need to initialise the environment.

# %%
env = gym_super_mario_bros.make('SuperMarioBros-v0')
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/envs/registration.py:594: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   f"The environment {id} is out of date. You should consider "
# /usr/local/lib/python3.7/dist-packages/gym/core.py:318: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/step_api_compatibility.py:40: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."

# %% [markdown]
# ### 3. Let environment know the input space.

# %%
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %% [markdown]
# Lets examine the number of "observations" that can result in the enviroment.

# %%
env.action_space
# Out:
# Discrete(7)

# %%
env.observation_space.shape
# Out:
# (240, 256, 3)

# %% [markdown]
# ### 4. Creating a simple loop for display.

# %%
done = True
for step in range(100):
    if done:
        env.reset()
    state, reward, done, info = env.step(env.action_space.sample())
    #print(state, reward, done, info)
    show_state(env,step,info)
#env.close()

# %% [markdown]
# ### Mario is up and running. Yay!
#
# `Note: if you uncomment the env.close() line you'll have to initialise environment again`
#
#
# ## Note on what we observe
#
# Observations
# If we ever want to do better than take random actions at each step, it’d probably be good to actually know what our actions are doing to the environment.
#
# The environment’s step function returns exactly what we need. In fact, step returns four values. These are:
#
# observation (object): an environment-specific object representing your observation of the environment. For example, pixel data from a camera, joint angles and joint velocities of a robot, or the board state in a board game.
# reward (float): amount of reward achieved by the previous action. The scale varies between environments, but the goal is always to increase your total reward.
# done (boolean): whether it’s time to reset the environment again. Most (but not all) tasks are divided up into well-defined episodes, and done being True indicates the episode has terminated. (For example, perhaps the pole tipped too far, or you lost your last life.)
# info (dict): diagnostic information useful for debugging. It can sometimes be useful for learning (for example, it might contain the raw probabilities behind the environment’s last state change). However, official evaluations of your agent are not allowed to use this for learning.
# This is just an implementation of the classic “agent-environment loop”. Each timestep, the agent chooses an action, and the environment returns an observation and a reward.
#
#
# The process gets started by calling reset(), which returns an initial observation. So a more proper way of writing the previous code would be to respect the done flag. (https://gym.openai.com/docs/#environments)

# %% [markdown]
# # PREPROCESS ENVIRONMENT

# %% [markdown]
# Lets make our pipeline more efficient with some quality of life changes. Lets start by installing torch, torchvision, torchaudio. (It should be already installed in kaggle but just to be sure).
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQyrn8kARfzWOySc97OsBa4v_dncfeNxB3GCcZA9Ufssdy7PP1--9FM8W8tMVdyLMt3k3Y&usqp=CAU)

# %%
#!pip install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio===0.10.1+cu113
# !pip install -q torch torchvision torchaudio

# %% [markdown]
# ## Using Stable Baselines RL algorithms

# %% [markdown]
# Stable Baselines is a set of improved implementations of Reinforcement Learning (RL) algorithms based on OpenAI Baselines. Which is what we would be using here.

# %%
# !pip install -q stable-baselines3[extra]
# Out:
#      |████████████████████████████████| 170 kB 14.4 MB/s
#      |████████████████████████████████| 1.5 MB 54.1 MB/s
#      |████████████████████████████████| 237 kB 51.1 MB/s
#      |████████████████████████████████| 1.6 MB 49.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 51 kB 6.2 MB/s
#   Building wheel for gym (setup.py) ... done
#   Building wheel for AutoROM.accept-rom-license (PEP 517) ... done

# %% [markdown]
# We use `GrayScaleObservation` to reduce the overhead of using color pictures while training.

# %%
from gym.wrappers import GrayScaleObservation

# %% [markdown]
# ### A note on VECTORIZED ENVIRONMENT in Stable Baselines
#
# Vectorized Environments are a method for stacking multiple independent environments into a single environment. Instead of training an RL agent on 1 environment per step, it allows us to train it on n environments per step. Because of this, actions passed to the environment are now a vector (of dimension n). It is the same for observations, rewards and end of episode signals (dones). In the case of non-array observation spaces such as Dict or Tuple, where different sub-spaces may have different shapes, the sub-observations are vectors (of dimension n). (https://stable-baselines.readthedocs.io/en/master/guide/vec_envs.html)

# %%
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
#from matplotlib import pyplot as plt

# %% [markdown]
# Lets initialise the env with added parameters.

# %%
# env = gym_super_mario_bros.make('SuperMarioBros-v0')
# env = JoypadSpace(env, SIMPLE_MOVEMENT)
env = GrayScaleObservation(env, keep_dim=True)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, 4, channels_order='last')

# %% [markdown]
# Starting from scratch with `env.reset()`.

# %%
state = env.reset()

# %%
state, reward, done, info = env.step([5])

# %% [markdown]
# ### Displaying sample input

# %%
plt.figure(figsize=(20,16))
for idx in range(state.shape[3]):
    plt.subplot(1,4,idx+1)
    plt.imshow(state[0][:,:,idx])
plt.show()

# %% [markdown]
# This is the sample game state world we are going to work with.

# %% [markdown]
# # TRAINING THE RL MODEL
#
# Its training time.
#
# ![](https://giffiles.alphacoders.com/260/2600.gif)

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback

# %% [markdown]
# PPO stands for proximal policy optimisation. Read more it here: https://arxiv.org/abs/1707.06347

# %%
class TrainAndLoggingCallback(BaseCallback):
    
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
    
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
    
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)
        return True

# %% [markdown]
# ### Note on Callbacks
# A callback is a set of functions that will be called at given stages of the training procedure. You can use callbacks to access internal state of the RL model during training. It allows one to do monitoring, auto saving, model manipulation, progress bars,

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %% [markdown]
# ## IMPORTANT
#
# ### If you increase the `check_freq` value you will get better result. but it takes more time. So its a question of how much time you have.
# For quick demostration sake I am keeping it low.

# %%
check_freq = 100
#check_freq = 100000

# %% [markdown]
# ### 1. Defining callback

# %%
callback = TrainAndLoggingCallback(check_freq=check_freq, save_path=CHECKPOINT_DIR)

# %% [markdown]
# ### 2. Initialising the PPO model.

# %%
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, n_steps=512)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# ### 3. Learning

# %%
model.learn(total_timesteps=check_freq, callback=callback)
# Out:
# Logging to ./logs/PPO_4
# ----------------------------
# | time/              |     |
# |    fps             | 169 |
# |    iterations      | 1   |
# |    time_elapsed    | 3   |
# |    total_timesteps | 512 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 98            |
# |    iterations           | 2             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 1024          |
# | train/                  |               |
# |    approx_kl            | 7.9827616e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.000542     |
# |    learning_rate        | 1e-06         |
# |    loss                 | 136           |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000431     |
# |    value_loss           | 353           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 86           |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 9.033247e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.0153      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.261        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00053     |
# |    value_loss           | 2.85         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 83            |
# |    iterations           | 4             |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 3.9922423e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0127       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.129         |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000444     |
# |    value_loss           | 1.18          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 5            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 7.687835e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.0417      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.125        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -5.1e-07     |
# |    value_loss           | 0.77         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 79            |
# |    iterations           | 6             |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 2.2919849e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0132        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.131         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000261     |
# |    value_loss           | 0.606         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 77            |
# |    iterations           | 7             |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 2.0317966e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0117       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.193         |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000134     |
# |    value_loss           | 0.436         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 76            |
# |    iterations           | 8             |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 7.3261326e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0324       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.139         |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000146     |
# |    value_loss           | 0.412         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 74            |
# |    iterations           | 9             |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 1.5608035e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0155       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0762        |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000158     |
# |    value_loss           | 0.255         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 74            |
# |    iterations           | 10            |
# |    time_elapsed         | 68            |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 2.0364998e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0134       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.158         |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.00043      |
# |    value_loss           | 0.452         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 74           |
# |    iterations           | 11           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 3.244623e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00454     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.125        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000511    |
# |    value_loss           | 0.268        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 74            |
# |    iterations           | 12            |
# |    time_elapsed         | 82            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.4373218e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00344      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0875        |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000261     |
# |    value_loss           | 0.243         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 73            |
# |    iterations           | 13            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 2.5804504e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00909      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.105         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000384     |
# |    value_loss           | 0.254         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 73            |
# |    iterations           | 14            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 1.4011399e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.000951      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.12          |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000197     |
# |    value_loss           | 0.23          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 73           |
# |    iterations           | 15           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 4.341302e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.000122     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0529       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000607    |
# |    value_loss           | 0.121        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 73            |
# |    iterations           | 16            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 2.8171577e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.000532      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0658        |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000406     |
# |    value_loss           | 0.14          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 17            |
# |    time_elapsed         | 120           |
# |    total_timesteps      | 8704          |
# | train/                  |               |
# |    approx_kl            | 0.00015021418 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0187        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 152           |
# |    n_updates            | 160           |
# |    policy_gradient_loss | 0.000381      |
# |    value_loss           | 385           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 18           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 7.865555e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0214       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 47.8         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000646    |
# |    value_loss           | 93.8         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 19            |
# |    time_elapsed         | 134           |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 4.8391987e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0305       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.148         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000137     |
# |    value_loss           | 1.34          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 20            |
# |    time_elapsed         | 140           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 1.0386924e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00089       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.135         |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 4.89e-05      |
# |    value_loss           | 0.918         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 21           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 10752        |
# | train/                  |              |
# |    approx_kl            | 3.924407e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0518       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.228        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000338    |
# |    value_loss           | 0.898        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 22           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 4.174281e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.115       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.105        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000219    |
# |    value_loss           | 0.566        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 23           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 2.892455e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00532     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.141        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000223    |
# |    value_loss           | 0.409        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 24            |
# |    time_elapsed         | 169           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 3.8196915e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.011        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.162         |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000408     |
# |    value_loss           | 0.47          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 25            |
# |    time_elapsed         | 177           |
# |    total_timesteps      | 12800         |
# | train/                  |               |
# |    approx_kl            | 3.9817067e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00489      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.159         |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000419     |
# |    value_loss           | 0.389         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 26            |
# |    time_elapsed         | 184           |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 4.4924556e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00232      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.179         |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000427     |
# |    value_loss           | 0.385         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 27            |
# |    time_elapsed         | 191           |
# |    total_timesteps      | 13824         |
# | train/                  |               |
# |    approx_kl            | 3.5147183e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00425      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.2           |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.00039      |
# |    value_loss           | 0.37          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 28            |
# |    time_elapsed         | 198           |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 4.9303286e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0173       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0945        |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000629     |
# |    value_loss           | 0.194         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 29            |
# |    time_elapsed         | 205           |
# |    total_timesteps      | 14848         |
# | train/                  |               |
# |    approx_kl            | 5.0403876e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0152       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.14          |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000547     |
# |    value_loss           | 0.314         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 30           |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 2.168445e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00132      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.129        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000226    |
# |    value_loss           | 0.376        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 31           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 15872        |
# | train/                  |              |
# |    approx_kl            | 5.757704e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00333      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0732       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000565    |
# |    value_loss           | 0.124        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 32           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 9.225577e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.011        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0617       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000731    |
# |    value_loss           | 0.138        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 33           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 16896        |
# | train/                  |              |
# |    approx_kl            | 0.0006919018 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.0465       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 119          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000966    |
# |    value_loss           | 295          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 34            |
# |    time_elapsed         | 241           |
# |    total_timesteps      | 17408         |
# | train/                  |               |
# |    approx_kl            | 3.4580822e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0832        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 48.4          |
# |    n_updates            | 330           |
# |    policy_gradient_loss | 0.000611      |
# |    value_loss           | 82.7          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 35           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 17920        |
# | train/                  |              |
# |    approx_kl            | 5.667121e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | -0.000646    |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.114        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -3.68e-05    |
# |    value_loss           | 1.25         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 36           |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 6.701541e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.111        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000305    |
# |    value_loss           | 0.786        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 37           |
# |    time_elapsed         | 262          |
# |    total_timesteps      | 18944        |
# | train/                  |              |
# |    approx_kl            | 7.967453e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.058        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0787       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00035     |
# |    value_loss           | 0.707        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 38            |
# |    time_elapsed         | 269           |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 0.00013920944 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.000232     |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.085         |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.00102      |
# |    value_loss           | 0.469         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 39            |
# |    time_elapsed         | 276           |
# |    total_timesteps      | 19968         |
# | train/                  |               |
# |    approx_kl            | 4.9932045e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0748        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0794        |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000243     |
# |    value_loss           | 0.324         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 40            |
# |    time_elapsed         | 283           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 2.6372261e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0378       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.113         |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000201     |
# |    value_loss           | 0.302         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 41            |
# |    time_elapsed         | 291           |
# |    total_timesteps      | 20992         |
# | train/                  |               |
# |    approx_kl            | 1.1897995e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.00225      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0843        |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -3.34e-05     |
# |    value_loss           | 0.24          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 42           |
# |    time_elapsed         | 298          |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 3.505347e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | -0.0374      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0587       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000264    |
# |    value_loss           | 0.21         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 43           |
# |    time_elapsed         | 305          |
# |    total_timesteps      | 22016        |
# | train/                  |              |
# |    approx_kl            | 8.143298e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.0165       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 38           |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 4.41e-05     |
# |    value_loss           | 76.3         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 44            |
# |    time_elapsed         | 312           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 5.6012417e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.262         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.141         |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000344     |
# |    value_loss           | 0.377         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 45            |
# |    time_elapsed         | 319           |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 2.2445107e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0321        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.12          |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -5.39e-05     |
# |    value_loss           | 0.321         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 46            |
# |    time_elapsed         | 326           |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 5.4970384e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.203         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.152         |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.00071      |
# |    value_loss           | 0.377         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 47            |
# |    time_elapsed         | 333           |
# |    total_timesteps      | 24064         |
# | train/                  |               |
# |    approx_kl            | 1.6828766e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.118         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0785        |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -9.59e-05     |
# |    value_loss           | 0.241         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 48            |
# |    time_elapsed         | 340           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 1.8223305e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.00963       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 4.45          |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -9.86e-05     |
# |    value_loss           | 13.4          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 49            |
# |    time_elapsed         | 348           |
# |    total_timesteps      | 25088         |
# | train/                  |               |
# |    approx_kl            | 0.00061711227 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0475        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 166           |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000343     |
# |    value_loss           | 505           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 50            |
# |    time_elapsed         | 355           |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 4.7410256e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.339         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.114         |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000168     |
# |    value_loss           | 1.71          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 51            |
# |    time_elapsed         | 362           |
# |    total_timesteps      | 26112         |
# | train/                  |               |
# |    approx_kl            | 4.9343216e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.334         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0768        |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000185     |
# |    value_loss           | 0.657         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 52           |
# |    time_elapsed         | 369          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 8.530833e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.053        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000709    |
# |    value_loss           | 0.501        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 53            |
# |    time_elapsed         | 376           |
# |    total_timesteps      | 27136         |
# | train/                  |               |
# |    approx_kl            | 3.4583732e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.239         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0718        |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.00024      |
# |    value_loss           | 0.373         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 54            |
# |    time_elapsed         | 383           |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 2.2482709e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0242       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0581        |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -2.63e-05     |
# |    value_loss           | 0.279         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 55            |
# |    time_elapsed         | 390           |
# |    total_timesteps      | 28160         |
# | train/                  |               |
# |    approx_kl            | 5.2645453e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0497        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.075         |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -0.000358     |
# |    value_loss           | 0.274         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 56           |
# |    time_elapsed         | 398          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 2.127327e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.0291       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0822       |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.000126    |
# |    value_loss           | 0.197        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 57           |
# |    time_elapsed         | 406          |
# |    total_timesteps      | 29184        |
# | train/                  |              |
# |    approx_kl            | 8.711836e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.0446       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 34.8         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.000623    |
# |    value_loss           | 74.1         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 58            |
# |    time_elapsed         | 413           |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 5.5774814e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0159        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0699        |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.000392     |
# |    value_loss           | 0.302         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 59            |
# |    time_elapsed         | 420           |
# |    total_timesteps      | 30208         |
# | train/                  |               |
# |    approx_kl            | 4.5056455e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.156         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.128         |
# |    n_updates            | 580           |
# |    policy_gradient_loss | -0.000267     |
# |    value_loss           | 0.315         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 60            |
# |    time_elapsed         | 427           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 4.0815095e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0119       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0843        |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -0.000357     |
# |    value_loss           | 0.244         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 61           |
# |    time_elapsed         | 434          |
# |    total_timesteps      | 31232        |
# | train/                  |              |
# |    approx_kl            | 5.508971e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.0571       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0949       |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.000418    |
# |    value_loss           | 0.211        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 62           |
# |    time_elapsed         | 441          |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 4.657125e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.00147      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0638       |
# ...
# |    explained_variance   | 0.076         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0581        |
# |    n_updates            | 1750          |
# |    policy_gradient_loss | -0.000773     |
# |    value_loss           | 0.182         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 177          |
# |    time_elapsed         | 1266         |
# |    total_timesteps      | 90624        |
# | train/                  |              |
# |    approx_kl            | 8.128048e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | -0.00995     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0554       |
# |    n_updates            | 1760         |
# |    policy_gradient_loss | -0.000355    |
# |    value_loss           | 0.151        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 178           |
# |    time_elapsed         | 1273          |
# |    total_timesteps      | 91136         |
# | train/                  |               |
# |    approx_kl            | 0.00026527594 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.74         |
# |    explained_variance   | -0.0214       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.063         |
# |    n_updates            | 1770          |
# |    policy_gradient_loss | -0.000775     |
# |    value_loss           | 0.151         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 179          |
# |    time_elapsed         | 1280         |
# |    total_timesteps      | 91648        |
# | train/                  |              |
# |    approx_kl            | 0.0006473558 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | -0.0395      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0447       |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 0.133        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 180          |
# |    time_elapsed         | 1287         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 4.512735e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | -0.0767      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0665       |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -6.3e-05     |
# |    value_loss           | 0.119        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 181           |
# |    time_elapsed         | 1294          |
# |    total_timesteps      | 92672         |
# | train/                  |               |
# |    approx_kl            | 0.00015706487 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.76         |
# |    explained_variance   | 0.0133        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.043         |
# |    n_updates            | 1800          |
# |    policy_gradient_loss | -0.000532     |
# |    value_loss           | 0.103         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 182           |
# |    time_elapsed         | 1301          |
# |    total_timesteps      | 93184         |
# | train/                  |               |
# |    approx_kl            | 0.00020478526 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.75         |
# |    explained_variance   | 0.0139        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0388        |
# |    n_updates            | 1810          |
# |    policy_gradient_loss | -0.000711     |
# |    value_loss           | 0.0996        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 183          |
# |    time_elapsed         | 1308         |
# |    total_timesteps      | 93696        |
# | train/                  |              |
# |    approx_kl            | 7.616426e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | -0.0461      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0486       |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.000341    |
# |    value_loss           | 0.103        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 184          |
# |    time_elapsed         | 1315         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0062939273 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | 0.297        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 137          |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | 0.00106      |
# |    value_loss           | 465          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 185           |
# |    time_elapsed         | 1322          |
# |    total_timesteps      | 94720         |
# | train/                  |               |
# |    approx_kl            | 4.9216324e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.68         |
# |    explained_variance   | 0.522         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 15.3          |
# |    n_updates            | 1840          |
# |    policy_gradient_loss | -0.00046      |
# |    value_loss           | 34            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 186          |
# |    time_elapsed         | 1329         |
# |    total_timesteps      | 95232        |
# | train/                  |              |
# |    approx_kl            | 5.671929e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | -0.0217      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.274        |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | 0.000611     |
# |    value_loss           | 1.23         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 187           |
# |    time_elapsed         | 1336          |
# |    total_timesteps      | 95744         |
# | train/                  |               |
# |    approx_kl            | 0.00041732844 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.69         |
# |    explained_variance   | -0.0204       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.103         |
# |    n_updates            | 1860          |
# |    policy_gradient_loss | -0.000765     |
# |    value_loss           | 0.763         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 188           |
# |    time_elapsed         | 1343          |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00020193763 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.68         |
# |    explained_variance   | 0.392         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 36.8          |
# |    n_updates            | 1870          |
# |    policy_gradient_loss | 0.000292      |
# |    value_loss           | 74.3          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 189         |
# |    time_elapsed         | 1351        |
# |    total_timesteps      | 96768       |
# | train/                  |             |
# |    approx_kl            | 0.000344757 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | -0.0152     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.173       |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.000663   |
# |    value_loss           | 1.4         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 190           |
# |    time_elapsed         | 1357          |
# |    total_timesteps      | 97280         |
# | train/                  |               |
# |    approx_kl            | 0.00029668328 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.7          |
# |    explained_variance   | -0.00854      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.149         |
# |    n_updates            | 1890          |
# |    policy_gradient_loss | -0.000599     |
# |    value_loss           | 0.866         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 191           |
# |    time_elapsed         | 1365          |
# |    total_timesteps      | 97792         |
# | train/                  |               |
# |    approx_kl            | 0.00074286014 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.71         |
# |    explained_variance   | -0.0155       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.123         |
# |    n_updates            | 1900          |
# |    policy_gradient_loss | -0.00195      |
# |    value_loss           | 0.7           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 192          |
# |    time_elapsed         | 1373         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0001513547 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | -0.00486     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.168        |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.000389    |
# |    value_loss           | 0.509        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 193           |
# |    time_elapsed         | 1381          |
# |    total_timesteps      | 98816         |
# | train/                  |               |
# |    approx_kl            | 0.00012014783 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.73         |
# |    explained_variance   | -0.029        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.121         |
# |    n_updates            | 1920          |
# |    policy_gradient_loss | -0.000302     |
# |    value_loss           | 0.439         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 194           |
# |    time_elapsed         | 1387          |
# |    total_timesteps      | 99328         |
# | train/                  |               |
# |    approx_kl            | 0.00010607415 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.74         |
# |    explained_variance   | 0.00328       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0981        |
# |    n_updates            | 1930          |
# |    policy_gradient_loss | -0.00028      |
# |    value_loss           | 0.338         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 195          |
# |    time_elapsed         | 1395         |
# |    total_timesteps      | 99840        |
# | train/                  |              |
# |    approx_kl            | 9.214168e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.0192       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0507       |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.000292    |
# |    value_loss           | 0.167        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 196           |
# |    time_elapsed         | 1403          |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 5.4655713e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.74         |
# |    explained_variance   | -0.00815      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0424        |
# |    n_updates            | 1950          |
# |    policy_gradient_loss | -0.000207     |
# |    value_loss           | 0.177         |
# -------------------------------------------

# %%
model.save('astatemodel')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7fb4c12b5ac2> in <module>
# ----> 1 model.save('astatemodel')
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## TEST IT OUT
#
# Here is how you test the algorithm.

# %%
#model = PPO.load('./astatemodel')
model = PPO.load('./train/best_model_10000')

# %%
state = env.reset()

# %%
state = env.reset()

#for step in range(10000):
for step in range(1000):
    if done:
        env.reset()
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    #print(state, reward, done, info)
    show_state(env,step,info)
#env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-d88c907642bb> in <module>
#       8     state, reward, done, info = env.step(action)
#       9     #print(state, reward, done, info)
# ---> 10     show_state(env,step,info)
#      11 #env.close()
#
# <ipython-input-4-826cbdbb8b12> in show_state(env, step, info)
#       7
#       8     display.clear_output(wait=True)
# ----> 9     display.display(plt.gcf())
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
# --> 537                                metadata={**default_metadata, **metadata})
#     538
#     539     def print_to_buffer(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ### NOTE:
# 1. Youll notice that on lower values of check_freq mario doesn't even know that he needs to get big inorder to jump over the first pipe.
# 2. Try increasing the check_freq value after initial run, more the value better trained our mario.

# %% [markdown]
# Thank you for reading!
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQxZPsJQ5H4SXIUa5uekV-HQZyjpRMmlmmArQ&usqp=CAU)
